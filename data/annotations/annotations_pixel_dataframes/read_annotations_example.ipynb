# %%
import pandas as pd
import pickle

# %%
# Voornes duin annotations.
with open('VoornesDuin_polyg2pixel_scaled_balanced_sample.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
#                 r         g         b         i      ndvi    height  \
# 0        0.198634  0.156793  0.083934  0.222754  0.877301  0.721569
# 1        0.227092  0.178243  0.116375  0.236597  0.858896  0.823529
# 2        0.148694  0.095782  0.057865  0.136454  0.839286  1.000000
# 3        0.267204  0.214881  0.124785  0.235204  0.888199  0.721569
# 4        0.310395  0.257858  0.191757  0.145529  0.708075  0.000000
# ...           ...       ...       ...       ...       ...       ...
# 3078210  0.332098  0.318251  0.306211  0.188905  0.688949  0.003922
# 3078211  0.534398  0.540724  0.522601  0.298477  0.757764  0.003922
# 3078212  0.341523  0.306762  0.274163  0.188535  0.677419  0.003922
# 3078213  0.467690  0.454137  0.413775  0.234878  0.726708  0.003922
# 3078214  0.560034  0.554752  0.555027  0.317253  0.708609  0.003922
#
#                label
# 0                Bos
# 1                Bos
# 2                Bos
# 3                Bos
# 4        Grijze duin
# ...

# %%
# Coepelduynen annotations.
df = pd.read_csv("annotaties_coepelduynen_to_pixel_scaled.csv")
df
# Out:
#          Unnamed: 0         r         g         b         i      ndvi  \
# 0                 0  0.316497  0.275428  0.255914  0.249149  0.852564
# 1                 1  0.318109  0.276328  0.258065  0.245319  0.846154
# 2                 2  0.317571  0.276328  0.257527  0.243617  0.839744
# 3                 3  0.318109  0.277228  0.257527  0.243830  0.839744
# 4                 4  0.321333  0.280828  0.262366  0.249787  0.846154
# ...             ...       ...       ...       ...       ...       ...
# 1088422       46164  0.503863  0.455155  0.383097  0.276638  0.709402
# 1088423       46165  0.503004  0.454124  0.382668  0.275645  0.709402
# 1088424       46166  0.497425  0.446392  0.374517  0.265056  0.692308
# 1088425       46167  0.494421  0.442268  0.367653  0.257445  0.683761
# 1088426       46168  0.502575  0.452062  0.380952  0.272005  0.700855
#
#            height                label  \
# 0        0.396078                 Gras
# 1        0.003922                 Gras
# ...

# %%
df['label'].unique()
# Out:
# array(['Gras', 'Zand', 'Struweel', 'Bos', 'Asfalt', 'Schaduw',
#        'Vochtige duinvallei'], dtype=object)
